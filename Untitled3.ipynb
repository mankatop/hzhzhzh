# %% [markdown]
# <a href="https://colab.research.google.com/github/mankatop/hzhzhzh/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization, UpSampling2D, MaxPool2D, Concatenate, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import tarfile
from sklearn.model_selection import train_test_split
import time
import random
import os
from PIL import Image
import cv2
import pandas as pd
import math
from os import path

# %%
def MAE(N, gt_i_j, pred_i_j):
  MAE = sum(math.abs(gt_i_j - pred_i_j) / N)

# %%
path = '/content/drive/MyDrive/train_set1/train_dataset_1'
goods = {}
images = []
input_shape = (416, 416)
num_of_classes = 368

# %%
# for filename in sorted(os.listdir(path)):
#   data = os.listdir(path + '/' + filename)
#   for f in data:
#     img = cv2.imread(path + '/' + filename + '/' + f)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img = np.array(img)
#     images.append(img)
#   goods[filename] = images
#   images = []

# %%
for i in range(len(os.listdir(path))):
  data = os.listdir(path + '/' + filename)
  for j in data:
    img = cv2.imread(path + '/' + filename + '/' + f)

# %%
from random import randint, shuffle
images = []
x = []
y = []
n = 0
lst = os.listdir(path)
for i in range(len(os.listdir(path))):
  for j in range(len(os.listdir(path + '/' + lst[i]))):
    x1 = sorted(os.listdir(path + '/' + lst[i]))[j]
    x2 = sorted(os.listdir(path + '/' + lst[i]))[randint(0, len(os.listdir(path + '/' + lst[i]))- 1)]
    y1 = os.listdir(path + '/' + lst[i])[j]
    y2 = os.listdir(path + '/' + lst[randint(0, len(os.listdir(path + '/' + lst[j]))- 1)])[j]
    if x1 != x2:
      bad_x = [path + '/' + lst[randint(0, i)] + '/' + y1, path + '/' + lst[i] + '/' + y2]
      huinya1 = bad_x[0].split('/')
      huinya2 = bad_x[1].split('/')
      if huinya1[-2] != huinya2[-2]:
        y.append(bad_x)
      cool_x = [path + '/' + lst[i] + '/' + x1, path + '/' + lst[i] + '/' + x2]
      x.append(cool_x)
      n += 1
    break
print(y)
# Out:
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1243/95.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/11.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/550/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/26.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1120/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/939/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1120/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/523/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1464/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/13.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2020/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/378.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/358/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/8.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/990/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/769/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2268/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/22.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2245/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/131.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/329/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/21.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2228/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2264/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/27.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/158/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/58.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1443/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/158/23.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1272/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2228/167.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2375/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/644/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1443/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/124/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/990/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1319/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2042/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/787/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1500/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/114.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/734/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1319/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/859/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2375/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1362/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/934/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2228/20.jpg', '/content/drive/MyDri ...

# %%
print(cool_x)
# Out:
# ['/content/drive/MyDrive/train_set1/train_dataset_1/2037/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2037/15.jpg']

# %%
len1 = len(x)
len2 = len(y)
the_min = 0
if len1 < len2:
  the_min = len1
else:
  the_min = len2


x = x[0:the_min]
y = y[0:the_min]

# %%
print(x)
print(y)
# Out:
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1243/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/1.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/117.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/550/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1120/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1120/21.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/939/0.png', '/content/drive/MyDrive/train_set1/train_dataset_1/939/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/523/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1464/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1464/54.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2020/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2020/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/358/587.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/990/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/990/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/769/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/769/18.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2268/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2245/15.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/329/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/329/17.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2228/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2228/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2264/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/158/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/158/31.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1443/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1443/104.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1272/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1272/1.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2375/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2375/109.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/644/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/124/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/124/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1319/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1319/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2042/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2042/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/787/0.png', '/content/drive/MyDrive/train_set1/train_dataset_1/787/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1500/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1500/22.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/734/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/734/59.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/859/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/859/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1362/0.jpg', '/content/drive/MyDrive/train_set1/train_data ...
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1243/95.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/11.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/550/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/26.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1120/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/939/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1120/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/523/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1464/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/13.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2020/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/378.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/358/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/8.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/990/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/769/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2268/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/22.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2245/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/131.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/329/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/21.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2228/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2264/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/27.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/158/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/58.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1443/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/158/23.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1272/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2228/167.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2375/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/644/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1443/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/124/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/990/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1319/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2042/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/787/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1500/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/114.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/734/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1319/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/859/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2375/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1362/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/934/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2228/20.jpg', '/content/drive/MyDri ...

# %%
print(len(x))
print(len(y))
# Out:
# 329
# 329

# %%
x_conc_y = x + y
shuffle(x_conc_y)

# %%
print(x_conc_y)

# %%
for sp in x:
  for path1 in sp:
      img = cv2.cvtColor(cv2.imread(path1), cv2.COLOR_BGR2RGB)
      img = np.array(img)

# %%
def siamese_model(input_shape, )
