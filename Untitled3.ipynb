# %% [markdown]
# <a href="https://colab.research.google.com/github/mankatop/hzhzhzh/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization, UpSampling2D, MaxPool2D, Concatenate, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import tarfile
from sklearn.model_selection import train_test_split
import time
import random
import os
from PIL import Image
import cv2
import pandas as pd
import math
from os import path

# %%
def MAE(N, gt_i_j, pred_i_j):
  MAE = sum(math.abs(gt_i_j - pred_i_j) / N)

# %%
path = '/content/drive/MyDrive/train_set1/train_dataset_1'
goods = {}
images = []
input_shape = (416, 416)
num_of_classes = 368

# %%
# for filename in sorted(os.listdir(path)):
#   data = os.listdir(path + '/' + filename)
#   for f in data:
#     img = cv2.imread(path + '/' + filename + '/' + f)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img = np.array(img)
#     images.append(img)
#   goods[filename] = images
#   images = []

# %%
for i in range(len(os.listdir(path))):
  data = os.listdir(path + '/' + filename)
  for j in data:
    img = cv2.imread(path + '/' + filename + '/' + f)

# %%
from random import randint, shuffle
images = []
x = []
y = []
lst = os.listdir(path)
for i in range(len(os.listdir(path))):
  for j in range(len(os.listdir(path + '/' + lst[i]))):
    y1 = os.listdir(path + '/' + lst[i])[j]
    y2 = os.listdir(path + '/' + lst[randint(0, len(os.listdir(path + '/' + lst[j]))- 1)])[j]
    bad_x = [path + '/' + lst[randint(0, i)] + '/' + y1, path + '/' + lst[i] + '/' + y2]
    huinya1 = bad_x[0].split('/')
    huinya2 = bad_x[1].split('/')
    if huinya1[-2] != huinya2[-2]:
      y.append(bad_x)
    break
print(y)
# Out:
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/11.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/550/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/26.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1120/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/939/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/523/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1464/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/939/378.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/358/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1464/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/769/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2268/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1464/22.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2245/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/21.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2228/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2264/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/27.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/158/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/58.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1443/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/23.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1272/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/167.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2375/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/939/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/644/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/124/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1319/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2042/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/787/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1500/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/769/114.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/734/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1362/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/20.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1714/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/934/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/487/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2020/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1225/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/158/0.png', '/content/drive/MyDrive/train_set1/train_dataset_1/1517/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1302/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/115.jpg', '/content/drive/MyDr ...

# %%
from random import randint
images = []
x = []
n = 0
lst = os.listdir(path)
for i in range(len(os.listdir(path))):
  for j in range(len(os.listdir(path + '/' + lst[i]))):
    if j < 10:
        x1 = sorted(os.listdir(path + '/' + lst[i]))[j]
        x2 = sorted(os.listdir(path + '/' + lst[i]))[randint(0, len(os.listdir(path + '/' + lst[i]))- 1)]
        if x1 != x2:
          x.append([path + '/' + lst[i] + '/' + x1, path + '/' + lst[i] + '/' + x2])
    else:
      break
print(x)
# Out:
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1243/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/7.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/100.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/56.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/101.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/45.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/100.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/103.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/52.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/104.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/55.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/105.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/90.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/106.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/71.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/8.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/1.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/5.jpg', '/content/drive/MyDrive/ ...

# %%
print(len(x))
# Out:
# 3174

# %%
len1 = len(x)
len2 = len(y)
the_min = 0
if len1 < len2:
  the_min = len1
else:
  the_min = len2


x = x[0:the_min]
y = y[0:the_min]

# %%
print(x)
print(y)
# Out:
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1243/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/7.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1243/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/100.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/56.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/101.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/45.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/100.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/103.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/52.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/104.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/55.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/105.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/90.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/106.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1488/71.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/6.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/7.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/8.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/1.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/0.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/0.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/2.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/4.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/8.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/5.jpg', '/content/drive/MyDrive/ ...
# [['/content/drive/MyDrive/train_set1/train_dataset_1/1488/5.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/758/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2063/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/11.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/550/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/26.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1120/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/550/9.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/939/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/523/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1488/10.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1464/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/939/378.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/358/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1464/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/769/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1243/4.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2268/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/1464/22.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2245/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/21.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2228/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2264/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/523/27.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/158/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/58.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1443/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2245/23.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1272/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/167.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2375/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/939/19.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/644/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/124/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/358/2.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1319/3.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/2042/26.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/787/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/644/102.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1500/11.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/769/114.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/734/10.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2268/3.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1362/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2264/20.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1714/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/934/18.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/487/6.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2020/1.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1225/95.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/158/0.png', '/content/drive/MyDrive/train_set1/train_dataset_1/1517/9.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/758/33.jpg', '/content/drive/MyDrive/train_set1/train_dataset_1/1302/5.jpg'], ['/content/drive/MyDrive/train_set1/train_dataset_1/2063/115.jpg', '/content/drive/MyDr ...

# %%
print(len(x))
print(len(y))
# Out:
# 329
# 329

# %%
x_conc_y = x + y
shuffle(x_conc_y)

# %%
print(x_conc_y)

# %%
for sp in x:
  for path1 in sp:
      img = cv2.cvtColor(cv2.imread(path1), cv2.COLOR_BGR2RGB)
      img = np.array(img)

# %%
def siamese_model(input_shape, )
